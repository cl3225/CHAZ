# %% [markdown]
# <a href="https://colab.research.google.com/github/cl3225/CHAZ/blob/main/HurricaneExample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ** Let's plot some hurricanes**

# %% [markdown]
# 1. follow the tropcal example, install tropcal

# %%
pip install tropycal
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 31.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tropycal: filename=tropycal-1.4-py3-none-any.whl size=242893 sha256=82e20ff30892f4db3e5c212a5dfb3d3abcbb4789a7d300522c2ef409524aa4b5
#   Stored in directory: /root/.cache/pip/wheels/1a/8e/1d/76c6127f82dea26846e4b61d5e4c0ef3142fcb874b69b46b01
# Successfully built tropycal
# ...

# %% [markdown]
# 2. You will find that you need to install cartopy as well, otherwaise you will see error message when making a plot

# %%
pip install cartopy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 29.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# 3. Now, load functions that you need, such as thoe read HURDAT2 and try to read data follow the example

# %%
from tropycal import tracks

# %%
basin = tracks.TrackDataset(basin='north_atlantic',include_btk=False)
# Out:
# --> Starting to read in HURDAT2 data
# --> Completed reading in HURDAT2 data (2.6 seconds)

# %%
storm = basin.get_storm(('michael',2018))

# %% [markdown]
# 4. what do data look like?

# %%
print(storm)
# Out:
# <tropycal.tracks.Storm>
# Storm Summary:
#     Maximum Wind:      140 knots
#     Minimum Pressure:  919 hPa
#     Start Time:        0600 UTC 07 October 2018
#     End Time:          1800 UTC 11 October 2018
#
# Variables:
#     time        (datetime) [2018-10-06 18:00:00 .... 2018-10-15 18:00:00]
#     extra_obs   (int64) [0 .... 0]
#     special     (str) [ .... ]
#     type        (str) [LO .... EX]
#     lat         (float64) [17.8 .... 41.2]
#     lon         (float64) [-86.6 .... -10.0]
#     vmax        (int64) [25 .... 35]
#     mslp        (int64) [1006 .... 1001]
#     wmo_basin   (str) [north_atlantic .... north_atlantic]
#
# More Information:
#     id:              AL142018
#     operational_id:  AL142018
#     name:            MICHAEL
#     year:            2018
#     season:          2018
#     basin:           north_atlantic
#     source_info:     NHC Hurricane Database
#     source:          hurdat
#     ace:             12.5
#     realtime:        False
# ...

# %% [markdown]
# 5. plot one storms. (Note that in the assignment, I am asking you to plot storms for one whole season)

# %%
storm.plot()
# Out:
# <GeoAxes: title={'left': 'Hurricane MICHAEL', 'right': '07 Oct 2018 – 11 Oct 2018\n140 kt • 919 hPa • 12.5 ACE'}>
